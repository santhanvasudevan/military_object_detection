# %%
import os
import csv
from collections import defaultdict

# Update these paths with your dataset structure
DATA_SPLITS = {
    'train': '/content/drive/MyDrive/extracted_zip/military_object_dataset/train/labels',
    'val': '/content/drive/MyDrive/extracted_zip/military_object_dataset/val/labels',
    'test': '/content/drive/MyDrive/extracted_zip/military_object_dataset/test/labels'
}

output_csv = '/content/drive/MyDrive/extracted_zip/military_object_dataset/class_distribution.csv'
class_split_counts = defaultdict(lambda: {'train': 0, 'val': 0, 'test': 0})

for split_name, label_dir in DATA_SPLITS.items():
    for file in os.listdir(label_dir):
        if file.endswith('.txt'):
            with open(os.path.join(label_dir, file), 'r') as f:
                for line in f:
                    try:
                        class_id = int(float(line.strip().split()[0]))
                        class_split_counts[class_id][split_name] += 1
                    except:
                        continue

# Write CSV in pivot format
all_splits = ['train', 'val', 'test']
with open(output_csv, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['class_id'] + all_splits)
    for class_id in sorted(class_split_counts.keys()):
        row = [class_id] + [class_split_counts[class_id].get(split, 0) for split in all_splits]
        writer.writerow(row)

print(f"Class-wise distribution saved to: {output_csv}")
# Out:
# Class-wise distribution saved to: /content/drive/MyDrive/extracted_zip/military_object_dataset/class_distribution.csv

# %%
import os
import shutil

ROOT_DIR = '/content/drive/MyDrive/extracted_zip/military_object_dataset'
SPLITS = ['train', 'val', 'test']
TARGET_MOVES = {
    11: [('val', 50), ('test', 50)],
    1:  [('test', 50)],
    7:  [('val', 8), ('test', 8)],
}
CLASSES_TO_REMOVE = [5, 9]

def get_all_label_paths(split):
    label_dir = os.path.join(ROOT_DIR, split, 'labels')
    return [os.path.join(label_dir, f) for f in os.listdir(label_dir) if f.endswith('.txt')]

def remove_classes_and_clean(class_ids):
    removed_count = 0
    for split in SPLITS:
        for label_path in get_all_label_paths(split):
            with open(label_path, 'r') as f:
                lines = f.readlines()
            new_lines = [line for line in lines if int(line.strip().split()[0]) not in class_ids]
            if not new_lines:
                # Remove both label and image
                os.remove(label_path)
                image_path = label_path.replace('/labels/', '/images/').replace('.txt', '.jpg')
                if os.path.exists(image_path):
                    os.remove(image_path)
                removed_count += 1
            else:
                with open(label_path, 'w') as f:
                    f.writelines(new_lines)
    print(f"Removed {removed_count} image-label pairs containing only classes {class_ids}")

def get_files_by_class(split, class_id):
    found = []
    for label_path in get_all_label_paths(split):
        with open(label_path, 'r') as f:
            lines = f.readlines()
        if any(int(line.strip().split()[0]) == class_id for line in lines):
            found.append(label_path)
    return found

def move_files(label_paths, dest_split):
    for label_path in label_paths:
        # Paths
        src_img = label_path.replace('/labels/', '/images/').replace('.txt', '.jpg')
        dst_lbl = label_path.replace('/train/', f'/{dest_split}/')
        dst_img = src_img.replace('/train/', f'/{dest_split}/')
        # Move
        os.makedirs(os.path.dirname(dst_lbl), exist_ok=True)
        os.makedirs(os.path.dirname(dst_img), exist_ok=True)
        shutil.move(label_path, dst_lbl)
        if os.path.exists(src_img):
            shutil.move(src_img, dst_img)

def move_target_classes():
    for cls_id, moves in TARGET_MOVES.items():
        src_files = get_files_by_class('train', cls_id)
        for dest_split, count in moves:
            to_move = src_files[:count]
            move_files(to_move, dest_split)
            src_files = src_files[count:]
            print(f"Moved {len(to_move)} class {cls_id} samples to {dest_split}")

if __name__ == "__main__":
    remove_classes_and_clean(CLASSES_TO_REMOVE)
    move_target_classes()
    print("Dataset update complete.")
# Out:
# Removed 705 image-label pairs containing only classes [5, 9]
# Moved 50 class 11 samples to val
# Moved 50 class 11 samples to test
# Moved 50 class 1 samples to test
# Moved 8 class 7 samples to val
# Moved 8 class 7 samples to test
# Dataset update complete.

# %%
import os
import csv
from collections import defaultdict

# Update these paths with your dataset structure
DATA_SPLITS = {
    'train': '/content/drive/MyDrive/extracted_zip/military_object_dataset/train/labels',
    'val': '/content/drive/MyDrive/extracted_zip/military_object_dataset/val/labels',
    'test': '/content/drive/MyDrive/extracted_zip/military_object_dataset/test/labels'
}

output_csv = '/content/drive/MyDrive/extracted_zip/military_object_dataset/class_distribution_final.csv'
class_split_counts = defaultdict(lambda: {'train': 0, 'val': 0, 'test': 0})

for split_name, label_dir in DATA_SPLITS.items():
    for file in os.listdir(label_dir):
        if file.endswith('.txt'):
            with open(os.path.join(label_dir, file), 'r') as f:
                for line in f:
                    try:
                        class_id = int(float(line.strip().split()[0]))
                        class_split_counts[class_id][split_name] += 1
                    except:
                        continue

# Write CSV in pivot format
all_splits = ['train', 'val', 'test']
with open(output_csv, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['class_id'] + all_splits)
    for class_id in sorted(class_split_counts.keys()):
        row = [class_id] + [class_split_counts[class_id].get(split, 0) for split in all_splits]
        writer.writerow(row)

print(f"Class-wise distribution saved to: {output_csv}")
# Out:
# Class-wise distribution saved to: /content/drive/MyDrive/extracted_zip/military_object_dataset/class_distribution_final.csv

# %%
import os
from pathlib import Path
import shutil

LABEL_DIR = '/content/drive/MyDrive/extracted_zip/military_object_dataset/train/labels'
IMAGE_DIR = '/content/drive/MyDrive/extracted_zip/military_object_dataset/train/images'
OUTPUT_DIR = '/content/drive/MyDrive/extracted_zip/augmented_dataset'

aug_target_classes = {7, 8}  # Soldier and civilian vehicle
files_to_augment = []

for label_file in os.listdir(LABEL_DIR):
    path = os.path.join(LABEL_DIR, label_file)
    with open(path, 'r') as f:
        lines = f.readlines()
    for line in lines:
        class_id = int(float(line.strip().split()[0]))  # robust parsing
        if class_id in aug_target_classes:
            files_to_augment.append(label_file)
            break  # Only need one matching class to include this file

print(f"\nTotal files to augment: {len(files_to_augment)}")
# Out:
# Total files to augment: 418

# %%
import cv2
import os
import glob
import albumentations as A

# ✅ Use Pascal VOC (absolute format)
augment = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.Rotate(limit=15, p=0.5),
    A.Blur(blur_limit=3, p=0.2)
], bbox_params=A.BboxParams(format='pascal_voc', label_fields=['class_labels'], min_visibility=0.3))

def load_yolo_labels(path):
    with open(path, 'r') as f:
        boxes = []
        classes = []
        for line in f:
            c, x, y, w, h = map(float, line.strip().split())
            boxes.append([x, y, w, h])
            classes.append(int(c))
        return boxes, classes

def save_yolo_labels(path, boxes, classes):
    with open(path, 'w') as f:
        for cls, box in zip(classes, boxes):
            f.write(f"{cls} {' '.join(map(str, box))}\n")

def clip_yolo_boxes(boxes):
    """
    Clip YOLO-format boxes (x_center, y_center, w, h) to be within [0, 1].
    """
    clipped = []
    for x, y, w, h in boxes:
        x1 = max(0, x - w / 2)
        y1 = max(0, y - h / 2)
        x2 = min(1, x + w / 2)
        y2 = min(1, y + h / 2)

        new_x = (x1 + x2) / 2
        new_y = (y1 + y2) / 2
        new_w = x2 - x1
        new_h = y2 - y1

        if new_w > 0 and new_h > 0:
            clipped.append([new_x, new_y, new_w, new_h])
    return clipped

# Setup
num_augmentations = 1
aug_img_dir = os.path.join(OUTPUT_DIR, 'images')
aug_lbl_dir = os.path.join(OUTPUT_DIR, 'labels')

# Clean previous output
for f in glob.glob(os.path.join(aug_img_dir, '*')):
    os.remove(f)
for f in glob.glob(os.path.join(aug_lbl_dir, '*')):
    os.remove(f)

print("Cleared existing augmented images and labels.")

# Main loop
for label_file in files_to_augment:
    img_file = label_file.replace('.txt', '.jpg')
    image_path = os.path.join(IMAGE_DIR, img_file)
    label_path = os.path.join(LABEL_DIR, label_file)

    image = cv2.imread(image_path)
    if image is None:
        print(f"Skipping missing image: {image_path}")
        continue

    h, w = image.shape[:2]

    for i in range(num_augmentations):
        boxes, classes = load_yolo_labels(label_path)
        boxes = clip_yolo_boxes(boxes)

        if not boxes:
            continue

        # Convert YOLO → absolute pixel coordinates (Pascal VOC format)
        abs_boxes = []
        for x, y, bw, bh in boxes:
            x_min = (x - bw / 2) * w
            y_min = (y - bh / 2) * h
            x_max = (x + bw / 2) * w
            y_max = (y + bh / 2) * h
            abs_boxes.append([x_min, y_min, x_max, y_max])

        # Apply augmentations
        try:
            augmented = augment(image=image, bboxes=abs_boxes, class_labels=classes)
        except Exception as e:
            print(f"Skipping {image_path} due to augmentation error: {e}")
            continue

        aug_image = augmented['image']
        aug_abs_boxes = augmented['bboxes']
        aug_classes = augmented['class_labels']

        # Convert Pascal VOC → YOLO format and normalize
        aug_yolo_boxes = []
        for x_min, y_min, x_max, y_max in aug_abs_boxes:
            x_min = max(0, min(w, x_min))
            y_min = max(0, min(h, y_min))
            x_max = max(0, min(w, x_max))
            y_max = max(0, min(h, y_max))

            bw = x_max - x_min
            bh = y_max - y_min
            x_center = x_min + bw / 2
            y_center = y_min + bh / 2

            x_center /= w
            y_center /= h
            bw /= w
            bh /= h

            if bw > 0 and bh > 0:
                aug_yolo_boxes.append([x_center, y_center, bw, bh])

        if aug_yolo_boxes:
            aug_img_name = f'aug_{i}_{img_file}'
            aug_lbl_name = f'aug_{i}_{label_file}'

            cv2.imwrite(os.path.join(aug_img_dir, aug_img_name), aug_image)
            save_yolo_labels(os.path.join(aug_lbl_dir, aug_lbl_name), aug_yolo_boxes, aug_classes)
# Out:
# Cleared existing augmented images and labels.
# Skipping /content/drive/MyDrive/extracted_zip/military_object_dataset/train/images/009464.jpg due to augmentation error: The lengths of bboxes and class_labels do not match. Got 2 and 3 respectively.
# Skipping /content/drive/MyDrive/extracted_zip/military_object_dataset/train/images/009590.jpg due to augmentation error: The lengths of bboxes and class_labels do not match. Got 5 and 6 respectively.
# Skipping /content/drive/MyDrive/extracted_zip/military_object_dataset/train/images/009621.jpg due to augmentation error: The lengths of bboxes and class_labels do not match. Got 7 and 8 respectively.
# Skipping /content/drive/MyDrive/extracted_zip/military_object_dataset/train/images/010042.jpg due to augmentation error: The lengths of bboxes and class_labels do not match. Got 6 and 7 respectively.
# Skipping /content/drive/MyDrive/extracted_zip/military_object_dataset/train/images/010114.jpg due to augmentation error: The lengths of bboxes and class_labels do not match. Got 5 and 6 respectively.
# Skipping /content/drive/MyDrive/extracted_zip/military_object_dataset/train/images/009184.jpg due to augmentation error: The lengths of bboxes and class_labels do not match. Got 54 and 55 respectively.
# Skipping /content/drive/MyDrive/extracted_zip/military_object_dataset/train/images/009212.jpg due to augmentation error: The lengths of bboxes and class_labels do not match. Got 45 and 46 respectively.

# %%
import os

LABEL_DIR = '/content/drive/MyDrive/extracted_zip/augmented_dataset/labels'

class_counts = {7: 0, 8: 0}  # civilian and trench

for label_file in os.listdir(LABEL_DIR):
    if label_file.endswith('.txt'):
        path = os.path.join(LABEL_DIR, label_file)
        with open(path, 'r') as f:
            lines = f.readlines()
        for line in lines:
            class_id = int(float(line.split()[0]))
            if class_id in class_counts:
                class_counts[class_id] += 1

print(f"Class 7 (civilian): {class_counts[7]} instances")
print(f"Class 8 (trench): {class_counts[8]} instances")
# Out:
# Class 7 (civilian): 452 instances
# Class 8 (trench): 424 instances

# %%
import os
import csv
from collections import defaultdict

# Update these paths with your dataset structure
DATA_SPLITS = {
    'train': '/content/drive/MyDrive/extracted_zip/military_object_dataset/train/labels',
    'val': '/content/drive/MyDrive/extracted_zip/military_object_dataset/val/labels',
    'test': '/content/drive/MyDrive/extracted_zip/military_object_dataset/test/labels'
}

output_csv = '/content/drive/MyDrive/extracted_zip/military_object_dataset/class_distribution_withaug_final.csv'
class_split_counts = defaultdict(lambda: {'train': 0, 'val': 0, 'test': 0})

for split_name, label_dir in DATA_SPLITS.items():
    for file in os.listdir(label_dir):
        if file.endswith('.txt'):
            with open(os.path.join(label_dir, file), 'r') as f:
                for line in f:
                    try:
                        class_id = int(float(line.strip().split()[0]))
                        class_split_counts[class_id][split_name] += 1
                    except:
                        continue

# Write CSV in pivot format
all_splits = ['train', 'val', 'test']
with open(output_csv, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['class_id'] + all_splits)
    for class_id in sorted(class_split_counts.keys()):
        row = [class_id] + [class_split_counts[class_id].get(split, 0) for split in all_splits]
        writer.writerow(row)

print(f"Class-wise distribution saved to: {output_csv}")
# Out:
# Class-wise distribution saved to: /content/drive/MyDrive/extracted_zip/military_object_dataset/class_distribution_withaug_final.csv

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.133-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.133-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 49.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 64.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.6 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.133 ultralytics-thop-2.0.14

# %%
# Copy the zip from Drive to local fast storage
# !cp /content/drive/MyDrive/copied_file.zip /content/

# Unzip it locally
# !unzip /content/copied_file.zip -d /content/military_OD_data/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011492.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011493.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011494.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011495.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011496.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011497.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011498.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011499.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011500.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011501.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011502.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011503.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011504.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011505.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011506.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011507.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011508.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011509.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011510.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011511.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011512.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011513.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011514.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011515.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011516.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011517.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011518.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011519.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011520.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011521.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011522.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011523.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011524.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011525.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011526.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011527.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011528.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011529.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011530.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011531.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011532.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011533.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011534.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011535.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011536.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011537.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011538.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011539.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011540.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011541.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011542.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011543.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011544.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011545.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011546.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011547.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011548.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011549.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011550.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011551.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011552.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011553.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011554.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011555.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011556.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011557.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011558.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011559.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011560.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011561.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011562.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011563.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011564.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011565.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011566.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011567.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011568.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011569.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011570.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011571.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011572.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011573.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011574.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011575.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011576.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011577.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011578.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011579.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011580.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011581.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011582.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011583.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011584.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011585.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011586.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011587.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011588.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011589.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011590.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011591.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011592.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011593.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011594.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011595.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011596.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011597.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011598.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011599.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011600.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011601.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011602.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011603.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011604.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011605.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011606.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011607.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011608.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011609.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011610.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011611.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011612.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011613.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011614.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011615.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011616.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011617.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011618.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011619.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011620.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011621.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011622.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011623.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011624.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011625.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011626.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011627.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011628.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011629.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011630.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011631.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011632.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011633.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011634.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011635.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011636.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011637.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011638.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011639.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011640.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011641.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011642.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011643.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011644.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011645.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011646.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011647.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011648.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011649.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011650.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011651.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011652.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011653.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011654.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011655.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011656.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011657.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011658.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011659.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011660.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011661.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011662.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011663.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011664.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011665.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011666.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011667.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011668.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011669.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011670.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011671.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011672.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011673.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011674.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011675.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011676.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011677.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011678.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011679.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011680.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011681.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011682.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011683.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011684.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011685.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011686.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011687.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011688.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011689.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011690.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011691.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011692.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011693.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011694.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011695.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011696.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011697.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011698.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011699.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011700.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011701.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011702.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011703.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011704.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011705.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011706.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011707.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011708.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011709.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011710.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011711.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011712.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011713.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011714.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011715.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011716.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011717.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011718.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011719.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011720.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011721.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011722.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011723.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011724.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011725.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011726.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011727.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011728.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011729.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011730.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011731.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011732.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011733.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011734.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011735.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011736.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011737.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011738.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011739.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011740.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011741.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011742.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011743.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011744.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011745.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011746.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011747.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011748.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011749.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011750.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011751.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011752.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011753.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011754.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011755.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011756.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011757.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011758.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011759.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011760.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011761.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011762.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011763.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011764.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011765.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011766.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011767.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011768.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011769.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011770.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011771.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011772.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011773.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011774.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011775.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011776.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011777.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011778.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011779.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011780.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011781.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011782.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011783.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011784.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/011785.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013238.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013239.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013240.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013241.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013242.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013243.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013244.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013245.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013246.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013247.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013248.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013249.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013250.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013251.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013252.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013253.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013254.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013255.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013256.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013257.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013258.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013259.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013260.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013261.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013262.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013263.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013264.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013265.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013266.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013267.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013268.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013269.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013270.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013271.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013272.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013273.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013274.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013275.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013276.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013277.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013278.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013279.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013280.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013281.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013282.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013283.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013284.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013285.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013286.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013287.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013288.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013289.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013290.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013291.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013292.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013293.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013294.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013295.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013296.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013297.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013298.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013299.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013300.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013301.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013302.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013303.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013304.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013305.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013306.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013307.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013308.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013309.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013310.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013311.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013312.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013313.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013314.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013315.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013316.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013317.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013318.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013319.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013320.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013321.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013322.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013323.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013324.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013325.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013326.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013327.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013328.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013329.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013330.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013331.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013332.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013333.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013334.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013335.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013336.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013337.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013338.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013339.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013340.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013341.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013342.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013343.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013344.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013345.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013346.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013347.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013348.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013349.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013350.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013351.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013352.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013353.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013354.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013355.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013356.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013357.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013358.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013359.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013360.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013361.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013362.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013363.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013364.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013365.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013366.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013367.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013368.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013369.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013370.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013371.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013372.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013373.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013374.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013375.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013376.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013377.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013378.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013379.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013380.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013381.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013382.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/013383.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016582.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016583.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016584.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016585.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016586.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016587.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016588.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016589.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016590.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016591.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016592.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016593.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016594.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016595.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016596.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016597.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016598.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016599.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016600.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016601.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016602.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016603.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016604.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016605.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016606.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016607.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016608.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016609.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016610.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016611.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016612.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016613.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016614.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016615.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016616.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016617.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016618.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016619.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016620.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016621.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016622.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016623.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016624.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016625.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016626.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016627.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016628.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016629.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016630.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016631.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016632.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016633.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016634.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016635.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016636.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016637.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016638.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016639.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016640.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016641.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016642.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016643.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016644.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016645.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016646.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016647.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016648.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016649.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016650.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016651.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016652.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016653.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016654.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016655.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016656.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016657.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016658.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016659.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016660.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016661.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016662.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016663.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016664.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016665.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016666.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016667.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016668.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016669.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016670.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016671.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016672.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016673.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016674.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016675.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016676.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016677.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016678.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016679.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016680.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016681.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016682.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016683.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016684.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016685.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016686.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016687.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016688.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016689.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016690.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016691.jpg
#   inflating: /content/military_OD_data/military_object_dataset/val/images/016692.jpg
# ...
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023649.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023650.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023651.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023652.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023653.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023654.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023655.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023656.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023657.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023658.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023659.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023660.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023661.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023662.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023663.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023664.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023665.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023666.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023667.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023668.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023669.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023670.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023671.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023672.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023673.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023674.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023675.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023676.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023677.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023678.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023679.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023680.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023681.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023682.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023683.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023684.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023685.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023686.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023687.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/023688.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026173.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026174.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026175.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026176.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026177.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026178.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026179.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026180.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026181.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026182.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026183.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026184.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026185.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026186.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026187.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026188.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026189.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026190.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026191.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026192.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026193.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026194.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026195.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026196.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026197.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026198.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026199.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026200.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026201.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026202.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026203.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026204.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026205.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026206.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026207.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026208.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026209.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026210.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026211.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026212.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026213.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026214.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026215.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026216.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026217.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026218.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026219.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026220.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026221.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026222.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026223.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026224.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026225.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026226.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026227.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026228.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026229.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026230.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026231.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026232.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026233.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026234.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026235.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026236.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026237.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026238.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026239.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026240.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026241.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026242.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026243.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026244.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026245.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026246.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026247.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026248.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026249.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026250.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026251.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026252.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026253.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026254.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026255.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026256.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026257.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026258.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026259.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026260.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026261.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026262.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026263.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026264.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026265.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026266.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026267.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026268.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026269.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026270.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026271.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026272.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026273.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026274.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026275.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026276.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026277.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026278.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026279.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026280.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026281.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026282.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026283.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026284.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026285.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026286.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026287.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026288.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026289.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026290.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026291.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026292.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026293.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026294.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026295.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026296.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026297.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026298.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026299.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026300.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026301.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026302.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026303.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026304.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026305.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026306.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026307.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026308.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026309.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026310.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026311.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026312.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026313.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026314.txt
#   inflating: /content/military_OD_data/military_object_dataset/val/labels/026315.txt

# %%
import os
import shutil
from ultralytics import YOLO

# === STEP 1: Set paths ===
# Google Drive paths (permanent storage)
drive_dataset_path = '/content/drive/MyDrive/extracted_zip/military_object_dataset'
drive_training_dir = '/content/drive/MyDrive/yolo_training/military_detection/yolov8_military'  # Saves here
drive_results_dir = os.path.join(drive_training_dir, 'predict_results')

# Local paths (fast access)
local_dataset_path = '/content/military_OD_data/military_object_dataset'
yaml_file_path = os.path.join(local_dataset_path, 'military_dataset.yaml')

# === STEP 3: Load pre-trained model (or resume from last checkpoint) ===
last_ckpt_path = os.path.join(drive_training_dir, 'weights', 'last.pt')
if os.path.exists(last_ckpt_path):
    print("🔁 Resuming from last checkpoint")
    model = YOLO(last_ckpt_path)
else:
    print("🆕 Starting fresh training")
    model = YOLO('yolov8n.pt')  # or yolov8s.pt, yolov8m.pt etc.

# === STEP 4: Train ===
model.train(
    data=yaml_file_path,
    epochs=50,
    imgsz=640,
    batch=16,
    patience=10,
    project='yolo_training',
    name='military_detection/yolov8_military',  # Folder path inside /content/drive/MyDrive/yolo_training/
    exist_ok=True,  # Don't raise error if folder exists
    verbose=True,
    resume=os.path.exists(last_ckpt_path)  # Ensures resume flag is set correctly
)

# === STEP 5: Validate (optional) ===
metrics = model.val()
print(metrics)

# === STEP 6: Predict on test set and save to Drive ===
results = model.predict(
    source=os.path.join(local_dataset_path, 'test/images'),
    save=True,
    save_txt=True,
    project='yolo_training',
    name='military_detection/yolov8_military/predict_results'
)

# === STEP 7: Export model to ONNX format (optional) ===
model.export(format='onnx')
# Out:
# 🆕 Starting fresh training
# Ultralytics 8.3.133 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/military_OD_data/military_object_dataset/military_dataset.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8_military, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=yolo_training, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=yolo_training/military_detection/yolov8_military, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=12
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    753652  ultralytics.nn.modules.head.Detect           [12, [64, 128, 256]]
# Model summary: 129 layers, 3,013,188 parameters, 3,013,172 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 188.5±350.4 MB/s, size: 123.9 KB)
# train: Scanning /content/military_OD_data/military_object_dataset/train/labels... 21978 images, 294 backgrounds, 0 corrupt: 100%|██████████| 21978/21978 [00:28<00:00, 773.63it/s]
# train: New cache created: /content/military_OD_data/military_object_dataset/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 22, len(boxes) = 43336. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 679.4±593.0 MB/s, size: 113.2 KB)
# val: Scanning /content/military_OD_data/military_object_dataset/val/labels... 2941 images, 273 backgrounds, 0 corrupt: 100%|██████████| 2941/2941 [00:02<00:00, 1373.25it/s]
# val: New cache created: /content/military_OD_data/military_object_dataset/val/labels.cache
# Plotting labels to yolo_training/military_detection/yolov8_military/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to yolo_training/military_detection/yolov8_military
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50       2.2G      1.301      2.668      1.409         57        640: 100%|██████████| 1374/1374 [08:08<00:00,  2.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 92/92 [00:36<00:00,  2.49it/s]
#                    all       2941       5081      0.585      0.295      0.262       0.15
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      2.89G       1.35       2.04      1.423         54        640: 100%|██████████| 1374/1374 [08:01<00:00,  2.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 92/92 [00:36<00:00,  2.49it/s]
#                    all       2941       5081      0.599      0.269      0.262      0.147
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.89G      1.454      1.996      1.497         36        640: 100%|██████████| 1374/1374 [07:46<00:00,  2.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 92/92 [00:36<00:00,  2.55it/s]
#                    all       2941       5081      0.292      0.254      0.175     0.0899
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      3.08G      1.492      1.895      1.531         38        640: 100%|██████████| 1374/1374 [07:52<00:00,  2.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 92/92 [00:36<00:00,  2.51it/s]
#                    all       2941       5081      0.366       0.29      0.256      0.141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50       3.1G      1.438      1.741      1.498         50        640: 100%|██████████| 1374/1374 [07:49<00:00,  2.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 92/92 [00:36<00:00,  2.53it/s]
#                    all       2941       5081      0.512      0.296      0.296      0.168
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50       3.1G      1.395      1.615      1.465         34        640: 100%|██████████| 1374/1374 [07:41<00:00,  2.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 92/92 [00:39<00:00,  2.32it/s]
#                    all       2941       5081      0.537      0.325      0.335      0.196
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      3.12G      1.362      1.534      1.436         45        640: 100%|██████████| 1374/1374 [07:44<00:00,  2.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 92/92 [00:36<00:00,  2.54it/s]
#                    all       2941       5081      0.546       0.34      0.345      0.201
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      3.12G      1.334      1.478      1.418         34        640: 100%|██████████| 1374/1374 [07:52<00:00,  2.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 92/92 [00:42<00:00,  2.19it/s]
#                    all       2941       5081      0.494      0.385      0.358       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      3.14G      1.313      1.427      1.396         32        640: 100%|██████████| 1374/1374 [07:36<00:00,  3.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 92/92 [00:40<00:00,  2.30it/s]
#                    all       2941       5081       0.43      0.406      0.358      0.217
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      3.14G      1.296       1.38      1.385         42        640: 100%|██████████| 1374/1374 [07:38<00:00,  2.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 92/92 [00:35<00:00,  2.58it/s]
#                    all       2941       5081      0.486      0.428      0.407      0.248
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      3.16G      1.274      1.346      1.371         32        640: 100%|██████████| 1374/1374 [07:42<00:00,  2.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 92/92 [00:34<00:00,  2.65it/s]
#                    all       2941       5081      0.615      0.385      0.425      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      3.16G      1.266      1.325      1.367         78        640:  65%|██████▌   | 898/1374 [05:00<02:47,  2.85it/s]
